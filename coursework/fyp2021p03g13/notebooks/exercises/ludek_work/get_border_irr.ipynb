# %%
import os
import sys
BASE_DIR = f"..{os.sep}..{os.sep}..{os.sep}"
USE_DEEPNOTE = True # In case you would open this notebook via Deepnote

# SCRIPTS IMPORT
scripts_path = os.path.abspath(os.path.join(f'{BASE_DIR}scripts'))

if scripts_path not in sys.path:
    # Add the scripts to the path
    sys.path.append(scripts_path)
    
    # Import the needed scripts
    from all_scripts import *
    
    # Remove the added path to avoid possible future conflicts
    sys.path.remove(scripts_path)
else:
    
    # Import the needed scripts
    from all_scripts import *
    
    # Remove the added path to avoid possible future conflicts
    sys.path.remove(scripts_path)

# PLOTS COLOR SETTING - see more here: https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette
PLOT_COLOR_SETTINGS = sns.color_palette("flare", as_cmap=True)

# %% [markdown]
# ### Example 1

# %%
from skimage.draw import disk

img = np.zeros((100, 100), dtype=np.uint8)
rr, cc = disk((50, 50), 25)
img[rr, cc] = 1
plt.imshow(img)
plt.title('Border Irregularity: '+ str(getBorderIrregularity(img)))
# Out:
# Text(0.5, 1.0, 'Border Irregularity: 0.0')

# %%
computeAsymmetry(img)
# Out:
# 9.899889888979765e-05

# %% [markdown]
# ### Example 2

# %%
# Redefine filenames related to image id's
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0001852" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)

# %%
computeAsymmetry(mask)
# Out:
# 0.018669998490459506

# %% [markdown]
# ### Example 3
# https://github.com/vcheplygina/fyp2021p3/tree/main/data/example_segmentation

# %%
# Redefine filenames related to image id's
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0004337" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)

# %%
computeAsymmetry(mask)
# Out:
# 0.0008971914760995785

# %% [markdown]
# ### Example 4

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0001852" + '_segmentation.png'
file_mask_healthy2 = "/datasets/examplesegmentation/" + "ISIC_0013561" + '_segmentation.png'
# Reread images and masks
fig, axs = plt.subplots(1, 3, figsize=(10, 5))
mask = plt.imread(file_mask_healthy)
mask2 = plt.imread(file_mask_healthy2)
axs[0].imshow(mask[725:1275][:,1250:1800])
axs[0].set_title('Asymmetry Value: '+ str(round(computeAsymmetry(mask),5)))
axs[0].set_xticklabels([]);axs[0].set_yticklabels([])
axs[1].imshow(img[20:80][:,20:80])
axs[1].set_title('Asymmetry Value: '+ str(round(computeAsymmetry(img),5)))
axs[1].set_xticklabels([]);axs[1].set_yticklabels([])
axs[2].imshow(mask2[510:1510][:,1000:2000])
axs[2].set_title('Asymmetry Value: '+ str(round(computeAsymmetry(mask2),5)))
axs[2].set_xticklabels([]);axs[2].set_yticklabels([]);

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0001852" + '_segmentation.png'
file_mask_healthy2 = "/datasets/examplesegmentation/" + "ISIC_0013561" + '_segmentation.png'
# Reread images and masks
fig, axs = plt.subplots(1, 3, figsize=(10, 5))
mask = plt.imread(file_mask_healthy)
mask2 = plt.imread(file_mask_healthy2)
axs[0].imshow(mask[725:1275][:,1250:1800])
axs[0].set_title('Border Irregularity: '+ str(round(getBorderIrregularity(mask),5)))
axs[0].set_xticklabels([]);axs[0].set_yticklabels([])
axs[1].imshow(img[20:80][:,20:80])
axs[1].set_title('Border Irregularity: '+ str(round(getBorderIrregularity(img),5)))
axs[1].set_xticklabels([]);axs[1].set_yticklabels([])
axs[2].imshow(mask2[510:1510][:,1000:2000])
axs[2].set_title('Border Irregularity: '+ str(round(getBorderIrregularity(mask2),5)))
axs[2].set_xticklabels([]);axs[2].set_yticklabels([]);

# %% [markdown]
# ### Example 5

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0001871" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)

# %%
computeAsymmetry(mask)
# Out:
# 0.018669998490459506

# %% [markdown]
# ### Example 6

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0012143" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)
plt.title('Border Irregularity: '+ str(getBorderIrregularity(mask)))
# Out:
# Text(0.5, 1.0, 'Border Irregularity: 2.4665796930503303')

# %%
computeAsymmetry(mask)
# Out:
# 0.01379622423030382

# %% [markdown]
# ### example 7

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0013561" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)

# %%
getBorderIrregularity(mask)
# Out:
# 2.447633135652379

# %% [markdown]
# # Example 8

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0014623" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)

# %%
computeAsymmetry(mask)
# Out:
# 0.0030565253279660454

# %% [markdown]
# # Example 9

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0014989" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)

# %%
computeAsymmetry(mask)
# Out:
# 0.014414883842649434

# %%
file_mask_healthy = "/datasets/examplesegmentation/" + "ISIC_0015062" + '_segmentation.png'

# Reread images and masks
mask = plt.imread(file_mask_healthy)
plt.imshow(mask)
isMaskTooCloseToBorder(mask, threshold = 1)
# find_leftright(mask)
# find_topbottom(mask)
# Out:
# True

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2a47fbf6-c653-4328-90db-f0771def66a6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
